# %%
import pandas as pd

# %%
houses = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/kc_house_data.csv")
titanic = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/titanic.csv")
netflix = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/netflix_titles.csv",sep="|")
btc = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/coin_Bitcoin.csv")
countries = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/countries of the world.csv")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic["age"].value_counts()
# Out:
# ?         263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
titanic["age"].replace(["?"],[None],inplace=True)

# %%
titanic["age"].astype("float")
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic["age_float"] = titanic["age"].astype("float")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 153.5+ KB

# %%
titanic["age"] = titanic["age"].astype("float")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 153.5+ KB

# %%
titanic["age"].mean()
# Out:
# 29.8811345124283

# %%
titanic["sex"].astype("category")
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: category
# Categories (2, object): ['female', 'male']

# %%
titanic["sex"]  = titanic["sex"].astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   category
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: category(1), float64(2), int64(4), object(8)
# memory usage: 144.7+ KB

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.embarked = titanic.embarked.astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   category
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   category
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
#  14  age_float  1046 non-null   float64
# dtypes: category(2), float64(2), int64(4), object(7)
# memory usage: 135.9+ KB

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/titanic.csv")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
pd.to_numeric(titanic["age"],errors="coerce")
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic["age"] = pd.to_numeric(titanic["age"],errors="coerce")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["age"].describe()
# Out:
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: age, dtype: float64

# %%
games = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/game_stats.csv")

# %%
games
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie         NaN    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee         NaN     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0
# 6       NaN         NaN     NaN      NaN       NaN

# %%
games.isna()
# Out:
#     name  league  points  assists  rebounds
# 0  False   False   False    False     False
# 1  False    True   False     True     False
# 2  False   False    True     True      True
# 3  False   False   False     True     False
# 4  False    True   False     True      True
# 5  False   False   False    False     False
# 6   True    True    True     True      True

# %%
games["league"].isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# Name: league, dtype: bool

# %%
games.dropna()
# Out:
#     name league  points  assists  rebounds
# 0    bob    nba    22.0      5.0      10.0
# 5  steph    nba    49.0      8.0      10.0

# %%
games["assists"].dropna()
# Out:
# 0    5.0
# 5    8.0
# Name: assists, dtype: float64

# %%
games.dropna(subset=["league","points"])
# Out:
#       name league  points  assists  rebounds
# 0      bob    nba    22.0      5.0      10.0
# 3  jackson    aba     9.0      NaN       2.0
# 5    steph    nba    49.0      8.0      10.0

# %%
games["league"].fillna("amateur",inplace=True)

# %%
games
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie     amateur    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee     amateur     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0
# 6       NaN     amateur     NaN      NaN       NaN

# %%
games.fillna({"points":0, "assists":"NONE"})
# Out:
#        name      league  points assists  rebounds
# 0       bob         nba    22.0     5.0      10.0
# 1    jessie     amateur    10.0    NONE       2.0
# 2       stu  euroleague     0.0    NONE       NaN
# 3   jackson         aba     9.0    NONE       2.0
# 4  timothee     amateur     8.0    NONE       NaN
# 5     steph         nba    49.0     8.0      10.0
# 6       NaN     amateur     0.0    NONE       NaN

# %%
sales = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/sales.csv")

# %%
sales
# Out:
#    rating  shipping_zip  billing_zip
# 0     5.0           NaN      81220.0
# 1     4.5       94931.0      94931.0
# 2     NaN       92625.0      92625.0
# 3     4.5       10003.0      10003.0
# 4     4.0           NaN      92660.0
# 5     NaN           NaN          NaN
# 6     NaN       60007.0      60007.0

# %%
sales.fillna({"shipping_zip":sales["billing_zip"]})
# Out:
#    rating  shipping_zip  billing_zip
# 0     5.0       81220.0      81220.0
# 1     4.5       94931.0      94931.0
# 2     NaN       92625.0      92625.0
# 3     4.5       10003.0      10003.0
# 4     4.0       92660.0      92660.0
# 5     NaN           NaN          NaN
# 6     NaN       60007.0      60007.0

# %% [markdown]
# # Exercise

# %%
import pandas as pd

# %%
netflix = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/netflix_titles.csv",sep="|")

# %%
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
netflix[netflix["country"].isna()]
# Out:
#       Unnamed: 0 show_id     type                                title  \
# 2              2      s3  TV Show                            Ganglands
# 3              3      s4  TV Show                Jailbirds New Orleans
# 5              5      s6  TV Show                        Midnight Mass
# 6              6      s7    Movie     My Little Pony: A New Generation
# 10            10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# ...          ...     ...      ...                                  ...
# 8718        8718   s8719    Movie               Westside vs. the World
# 8759        8759   s8760    Movie               World's Weirdest Homes
# 8783        8783   s8784  TV Show                                 Yoko
# 8785        8785   s8786  TV Show                                  YOM
# 8803        8803   s8804  TV Show                          Zombie Dumb
#
#                            director  \
# 2                   Julien Leclercq
# 3                               NaN
# ...

# %%
netflix[netflix["director"].isna()]
# Out:
#       Unnamed: 0 show_id     type                                title  \
# 1              1      s2  TV Show                        Blood & Water
# 3              3      s4  TV Show                Jailbirds New Orleans
# 4              4      s5  TV Show                         Kota Factory
# 10            10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 14            14     s15  TV Show      Crime Stories: India Detectives
# ...          ...     ...      ...                                  ...
# 8795        8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V
# 8796        8796   s8797  TV Show                           Yunus Emre
# 8797        8797   s8798  TV Show                            Zak Storm
# 8800        8800   s8801  TV Show                   Zindagi Gulzar Hai
# 8803        8803   s8804  TV Show                          Zombie Dumb
#
#      director                                               cast  \
# ...

# %%
netflix.dropna()
# Out:
#       Unnamed: 0 show_id     type                          title  \
# 7              7      s8    Movie                        Sankofa
# 8              8      s9  TV Show  The Great British Baking Show
# 9              9     s10    Movie                   The Starling
# 12            12     s13    Movie                   Je Suis Karl
# 24            24     s25    Movie                          Jeans
# ...          ...     ...      ...                            ...
# 8801        8801   s8802    Movie                        Zinzana
# 8802        8802   s8803    Movie                         Zodiac
# 8804        8804   s8805    Movie                     Zombieland
# 8805        8805   s8806    Movie                           Zoom
# 8806        8806   s8807    Movie                         Zubaan
#
#                  director                                               cast  \
# 7            Haile Gerima  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# ...

# %%
netflix.dropna(axis=1)
# Out:
#       Unnamed: 0 show_id     type                  title  release_year  \
# 0              0      s1    Movie   Dick Johnson Is Dead          2020
# 1              1      s2  TV Show          Blood & Water          2021
# 2              2      s3  TV Show              Ganglands          2021
# 3              3      s4  TV Show  Jailbirds New Orleans          2021
# 4              4      s5  TV Show           Kota Factory          2021
# ...          ...     ...      ...                    ...           ...
# 8802        8802   s8803    Movie                 Zodiac          2007
# 8803        8803   s8804  TV Show            Zombie Dumb          2018
# 8804        8804   s8805    Movie             Zombieland          2009
# 8805        8805   s8806    Movie                   Zoom          2006
# 8806        8806   s8807    Movie                 Zubaan          2015
#
#                                               listed_in  \
# 0                                         Documentaries
# ...

# %%
netflix.dropna(subset=["director","cast"])
# Out:
#       Unnamed: 0 show_id     type                             title  \
# 2              2      s3  TV Show                         Ganglands
# 5              5      s6  TV Show                     Midnight Mass
# 6              6      s7    Movie  My Little Pony: A New Generation
# 7              7      s8    Movie                           Sankofa
# 8              8      s9  TV Show     The Great British Baking Show
# ...          ...     ...      ...                               ...
# 8801        8801   s8802    Movie                           Zinzana
# 8802        8802   s8803    Movie                            Zodiac
# 8804        8804   s8805    Movie                        Zombieland
# 8805        8805   s8806    Movie                              Zoom
# 8806        8806   s8807    Movie                            Zubaan
#
#                            director  \
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# ...

# %%
netflix.loc[netflix["rating"].isna(),"rating"] = "TV-MA"

# %%
netflix["country"].value_counts().index[0]
# Out:
# 'United States'

# %%
netflix["country"].fillna(netflix["country"].value_counts().index[0],inplace=True)

# %%
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...
