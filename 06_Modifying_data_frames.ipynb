# %%
import pandas as pd

# %%
houses = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/kc_house_data.csv")
titanic = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/titanic.csv")
netflix = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/netflix_titles.csv",sep="|")
btc = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/coin_Bitcoin.csv")
countries = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/countries of the world.csv")

# %%
countries.set_index("Country",inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
btc.drop(labels="Symbol",axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
# btc.drop(labels=["SNo","Name","Symbol"],axis=1)
btc.drop(columns=["SNo","Name","Symbol"])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
btc[["Date","High","Low"]]
# Out:
#                      Date          High           Low
# 0     2013-04-29 23:59:59    147.488007    134.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003
# 2     2013-05-01 23:59:59    139.889999    107.720001
# 3     2013-05-02 23:59:59    125.599998     92.281898
# 4     2013-05-03 23:59:59    108.127998     79.099998
# ...                   ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169
#
# [2991 rows x 3 columns]

# %%
countries
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
# ...                                              ...         ...
# West Bank        NEAR EAST                               2460492
# Western Sahara   NORTHERN AFRICA                          273008
# Yemen            NEAR EAST                              21456188
# Zambia           SUB-SAHARAN AFRICA                     11502010
# Zimbabwe         SUB-SAHARAN AFRICA                     12236805
#
#                  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                       48,0
# ...

# %%
countries.drop(["Zambia ","Uganda "])
# Out:
#                                                  Region  Population  \
# Country
# Afghanistan               ASIA (EX. NEAR EAST)             31056997
# Albania             EASTERN EUROPE                          3581655
# Algeria             NORTHERN AFRICA                        32930091
# American Samoa      OCEANIA                                   57794
# Andorra             WESTERN EUROPE                            71201
# ...                                                 ...         ...
# Wallis and Futuna   OCEANIA                                   16025
# West Bank           NEAR EAST                               2460492
# Western Sahara      NORTHERN AFRICA                          273008
# Yemen               NEAR EAST                              21456188
# Zimbabwe            SUB-SAHARAN AFRICA                     12236805
#
#                     Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan                 647500                       48,0
# ...

# %%
btc.sort_index(ascending=False)
btc.drop(2990)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2985  2986  Bitcoin    BTC  2021-07-01 23:59:59  35035.982712  32883.781226
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
#
# ...

# %%
countries.drop(countries.index[10:])
# Out:
#                                                  Region  Population  \
# Country
# Afghanistan               ASIA (EX. NEAR EAST)             31056997
# Albania             EASTERN EUROPE                          3581655
# Algeria             NORTHERN AFRICA                        32930091
# American Samoa      OCEANIA                                   57794
# Andorra             WESTERN EUROPE                            71201
# Angola              SUB-SAHARAN AFRICA                     12127071
# Anguilla                        LATIN AMER. & CARIB           13477
# Antigua & Barbuda               LATIN AMER. & CARIB           69108
# Argentina                       LATIN AMER. & CARIB        39921833
# Armenia                            C.W. OF IND. STATES      2976372
#
#                     Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan                 647500                       48,0
# Albania                      28748                      124,6
# ...

# %%
titanic["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
titanic["species"] = "Human"

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses.insert(0,"county","King County")

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
houses["Sale_price"] = houses["price"]

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
houses.insert(3,"num_bedrooms",houses["bedrooms"])

# %%
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King County  7129300520  20141013T000000             3  221900.0
# 1      King County  6414100192  20141209T000000             3  538000.0
# 2      King County  5631500400  20150225T000000             2  180000.0
# 3      King County  2487200875  20141209T000000             4  604000.0
# 4      King County  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000             3  360000.0
# 21609  King County  6600060120  20150223T000000             4  400000.0
# 21610  King County  1523300141  20140623T000000             2  402101.0
# 21611  King County   291310100  20150116T000000             3  400000.0
# 21612  King County  1523300157  20141015T000000             2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# ...

# %%
titanic.drop(columns="species",inplace=True)

# %%
titanic["parch"]
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: parch, Length: 1309, dtype: int64

# %%
titanic["sibsp"]
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sibsp, Length: 1309, dtype: int64

# %%
titanic["parch"] + titanic["sibsp"]
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
titanic["num_relatives"] = titanic["sibsp"] + titanic["parch"]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sort_values("num_relatives",ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
#       sibsp  parch     ticket   fare cabin embarked boat body  \
# ...

# %%
titanic[titanic.survived == 1].sort_values("num_relatives",ascending=False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch   ticket      fare        cabin embarked boat  \
# ...

# %%
solo_passengers = titanic["num_relatives"] == 0
titanic[solo_passengers].sex.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
titanic.sex.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
houses["price_sqrt"] = houses["price"]/houses["sqft_living"]
houses
# Out:
#             county          id             date  num_bedrooms     price  \
# 0      King County  7129300520  20141013T000000             3  221900.0
# 1      King County  6414100192  20141209T000000             3  538000.0
# 2      King County  5631500400  20150225T000000             2  180000.0
# 3      King County  2487200875  20141209T000000             4  604000.0
# 4      King County  1954400510  20150218T000000             3  510000.0
# ...            ...         ...              ...           ...       ...
# 21608  King County   263000018  20140521T000000             3  360000.0
# 21609  King County  6600060120  20150223T000000             4  400000.0
# 21610  King County  1523300141  20140623T000000             2  402101.0
# 21611  King County   291310100  20150116T000000             3  400000.0
# 21612  King County  1523300157  20141015T000000             2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
houses.sort_values("price_sqrt",ascending=False).head(50).zipcode.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
btc.set_index("Date",inplace=True)

# %%
btc["change"] = btc.Close - btc.Open

# %%
btc.change
# Out:
# Date
# 2013-04-29 23:59:59      10.095993
# 2013-04-30 23:59:59      -5.000000
# 2013-05-01 23:59:59     -22.010002
# 2013-05-02 23:59:59     -11.169998
# 2013-05-03 23:59:59      -8.500000
#                           ...
# 2021-07-02 23:59:59     347.448412
# 2021-07-03 23:59:59     814.127040
# 2021-07-04 23:59:59     622.214900
# 2021-07-05 23:59:59   -1538.341974
# 2021-07-06 23:59:59     511.683796
# Name: change, Length: 2991, dtype: float64

# %%
btc.sort_values("change",ascending=False)
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2021-02-08 23:59:59  2843  Bitcoin    BTC  46203.931437  38076.322807
# 2021-04-26 23:59:59  2920  Bitcoin    BTC  54288.002155  48852.796843
# 2021-03-01 23:59:59  2864  Bitcoin    BTC  49784.015290  45115.093115
# 2021-02-19 23:59:59  2854  Bitcoin    BTC  56113.650547  50937.275722
# 2021-04-30 23:59:59  2924  Bitcoin    BTC  57900.719988  53129.600877
# ...                   ...      ...    ...           ...           ...
# 2021-04-18 23:59:59  2912  Bitcoin    BTC  61057.456509  52829.535926
# 2021-01-21 23:59:59  2825  Bitcoin    BTC  35552.679497  30250.749639
# 2021-02-23 23:59:59  2858  Bitcoin    BTC  54204.929756  45290.590268
# 2021-05-19 23:59:59  2943  Bitcoin    BTC  43546.116485  30681.496912
# 2021-05-12 23:59:59  2936  Bitcoin    BTC  57939.362415  49150.533875
#
#                              Open         Close        Volume     Marketcap  \
# Date
# ...

# %%
btc["delta"] = btc["High"] - btc["Low"]

# %%
btc["delta"].sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Exercise

# %%
import pandas as pd

# %%
biden_tweets = pd.read_csv("DataAnalysisCourseMaterials/DataAnalysis/data/JoeBidenTweets.csv")
biden_tweets
# Out:
#                        id         timestamp  \
# 0               361388562  2007-10-24 22:45
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                     url  \
# 0         https://twitter.com/JoeBiden/status/361388562
# 1         https://twitter.com/JoeBiden/status/543984392
# 2     https://twitter.com/JoeBiden/status/1892872273...
# 3     https://twitter.com/JoeBiden/status/1892873500...
# 4     https://twitter.com/JoeBiden/status/1893396506...
# ...                                                 ...
# ...

# %%
biden_tweets.drop(columns="url")
# Out:
#                        id         timestamp  \
# 0               361388562  2007-10-24 22:45
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                   tweet  replies  retweets  \
# 0     Tune in 11:30 ET tomorrow for a live webcast o...       19         5
# 1     Iowans, there's a good chance there's a Biden ...       13        16
# 2     We're excited to announce that @JoeBiden is be...       21        82
# 3     Campaign staff will run this account to keep y...      144        76
# ...

# %%
biden_tweets.drop(361388562,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3078/1435094108.py in <module>
# ----> 1 biden_tweets.drop(361388562,axis=0)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
biden_tweets["user"] = "Joe Biden"

# %%
biden_tweets["ratio"] = biden_tweets["replies"] + biden_tweets["retweets"]

# %%
biden_tweets.sort_values("ratio",ascending=False).head(10)

# %%
biden_tweets["reactions"] = biden_tweets["replies"] + biden_tweets["retweets"]  + biden_tweets["likes"] + biden_tweets["quotes"]

# %%
biden_tweets

# %%
biden_tweets.sort_values("reactions",ascending=False).head()

# %%
countries
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
# ...                                              ...         ...
# West Bank        NEAR EAST                               2460492
# Western Sahara   NORTHERN AFRICA                          273008
# Yemen            NEAR EAST                              21456188
# Zambia           SUB-SAHARAN AFRICA                     11502010
# Zimbabwe         SUB-SAHARAN AFRICA                     12236805
#
#                  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                       48,0
# ...

# %%
mapper= {"Region":"regional_indicator"}
countries.rename(columns=mapper)
# Out:
#                                   regional_indicator  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
# ...                                              ...         ...
# West Bank        NEAR EAST                               2460492
# Western Sahara   NORTHERN AFRICA                          273008
# Yemen            NEAR EAST                              21456188
# Zambia           SUB-SAHARAN AFRICA                     11502010
# Zimbabwe         SUB-SAHARAN AFRICA                     12236805
#
#                  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                       48,0
# ...

# %%
mapper = {"Finland":"finland","Denmark":"denmark"}
countries.rename(index=mapper)
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
# ...                                              ...         ...
# West Bank        NEAR EAST                               2460492
# Western Sahara   NORTHERN AFRICA                          273008
# Yemen            NEAR EAST                              21456188
# Zambia           SUB-SAHARAN AFRICA                     11502010
# Zimbabwe         SUB-SAHARAN AFRICA                     12236805
#
#                  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                       48,0
# ...
